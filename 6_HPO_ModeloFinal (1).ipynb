# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.6.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.1)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.6.0-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 6.4 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.6.0

# %%
import pandas as pd
import numpy as np
import holidays
import time
import optuna

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import TimeSeriesSplit
from lightgbm import LGBMRegressor

# %%
df = pd.read_csv('/content/drive/MyDrive/ProbEstatistica/1_ano_dados_data_center_limpa.csv')
df.set_index(df["timestamp"], inplace=True)
df.drop(columns=["timestamp"],inplace=True)
df.index = pd.to_datetime(df.index)

# %%
import pandas as pd
import numpy as np
import holidays
import optuna
import time

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_percentage_error
from lightgbm import LGBMRegressor


def tunar_lightgbm_temporal_split(df, n_lags=4, test_size=0.2, n_trials=30, seed=42):
    """
    Faz tuning dos hiperparâmetros do LightGBM usando Optuna com split temporal fixo (80/20).
    """

    df = df.copy()
    df.index = pd.to_datetime(df.index)

    # === Features temporais ===
    df['hora'] = df.index.hour
    df['dia_semana'] = df.index.dayofweek
    df['mes'] = df.index.month
    feriados_br = holidays.Brazil()
    df['feriado'] = df.index.map(lambda x: 1 if x in feriados_br else 0)

    # === Lags ===
    for i in range(1, n_lags + 1):
        df[f'lag_{i}'] = df['requisicoes'].shift(i)

    df = df.dropna()

    X = df.drop(columns='requisicoes')
    y = df['requisicoes']

    # === Split temporal 80/20 ===
    split_idx = int(len(df) * (1 - test_size))
    X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
    y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]

    # === Padronização ===
    scaler = StandardScaler()
    X_train_scaled = pd.DataFrame(
        scaler.fit_transform(X_train),
        index=X_train.index,
        columns=X_train.columns
    )
    X_test_scaled = pd.DataFrame(
        scaler.transform(X_test),
        index=X_test.index,
        columns=X_test.columns
    )

    # === Função objetivo para o Optuna ===
    def objective(trial):
        params = {
            "n_estimators": 500,
            "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
            "num_leaves": trial.suggest_int("num_leaves", 20, 200),
            "max_depth": trial.suggest_int("max_depth", 3, 15),
            "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
            "subsample": trial.suggest_float("subsample", 0.5, 1.0),
            "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
            "reg_alpha": trial.suggest_float("reg_alpha", 1e-3, 10.0, log=True),
            "reg_lambda": trial.suggest_float("reg_lambda", 1e-3, 10.0, log=True),
            "random_state": seed,
            "n_jobs": -1,
            "verbosity": -1
        }

        model = LGBMRegressor(**params)
        model.fit(X_train_scaled, y_train)

        y_pred = model.predict(X_test_scaled)
        mape = mean_absolute_percentage_error(y_test, y_pred)

        return mape

    # === Otimização com Optuna ===
    study = optuna.create_study(direction="minimize", study_name="LightGBM_TemporalSplit_Tuning")
    study.optimize(objective, n_trials=n_trials, show_progress_bar=True)

    print("\nMelhores hiperparâmetros encontrados:")
    for k, v in study.best_params.items():
        print(f"  {k}: {v}")
    print(f"\nMAPE (validação 80/20 temporal): {study.best_value:.4f}")

    return study

# %%
study = tunar_lightgbm_temporal_split(df)
# Out:
# [I 2025-11-12 23:02:06,544] A new study created in memory with name: LightGBM_TemporalSplit_Tuning
#   0%|          | 0/30 [00:00<?, ?it/s]
# [I 2025-11-12 23:02:14,659] Trial 0 finished with value: 0.12423704545347355 and parameters: {'learning_rate': 0.09133160171900243, 'num_leaves': 61, 'max_depth': 8, 'min_child_samples': 37, 'subsample': 0.8365339200914359, 'colsample_bytree': 0.6929037016192361, 'reg_alpha': 9.490200098566147, 'reg_lambda': 0.05622493277355228}. Best is trial 0 with value: 0.12423704545347355.
# [I 2025-11-12 23:02:16,141] Trial 1 finished with value: 0.11958174177877369 and parameters: {'learning_rate': 0.02949938785302991, 'num_leaves': 63, 'max_depth': 9, 'min_child_samples': 34, 'subsample': 0.6891687772265828, 'colsample_bytree': 0.8633860196577965, 'reg_alpha': 0.46066135867717156, 'reg_lambda': 0.2706184918985331}. Best is trial 1 with value: 0.11958174177877369.
# [I 2025-11-12 23:02:16,690] Trial 2 finished with value: 0.11892891517823548 and parameters: {'learning_rate': 0.054750255414775316, 'num_leaves': 74, 'max_depth': 4, 'min_child_samples': 25, 'subsample': 0.7238938091112218, 'colsample_bytree': 0.93482335608962, 'reg_alpha': 0.01236923050666119, 'reg_lambda': 0.4084847582572069}. Best is trial 2 with value: 0.11892891517823548.
# [I 2025-11-12 23:02:17,175] Trial 3 finished with value: 0.11682934342392332 and parameters: {'learning_rate': 0.010350367963553297, 'num_leaves': 78, 'max_depth': 4, 'min_child_samples': 25, 'subsample': 0.9469695076724929, 'colsample_bytree': 0.6163901326744559, 'reg_alpha': 2.557136127009988, 'reg_lambda': 0.0014161366202215515}. Best is trial 3 with value: 0.11682934342392332.
# [I 2025-11-12 23:02:18,557] Trial 4 finished with value: 0.11758729743664975 and parameters: {'learning_rate': 0.01276041325662731, 'num_leaves': 71, 'max_depth': 11, 'min_child_samples': 44, 'subsample': 0.7176081664059348, 'colsample_bytree': 0.5799025333154533, 'reg_alpha': 0.0021686372822669713, 'reg_lambda': 0.9318913219491023}. Best is trial 3 with value: 0.11682934342392332.
# [I 2025-11-12 23:02:20,475] Trial 5 finished with value: 0.1265479121685332 and parameters: {'learning_rate': 0.1764715216826953, 'num_leaves': 130, 'max_depth': 13, 'min_child_samples': 20, 'subsample': 0.9819287867994406, 'colsample_bytree': 0.5829777063469972, 'reg_alpha': 1.5989014824401795, 'reg_lambda': 0.0035103695706483837}. Best is trial 3 with value: 0.11682934342392332.
# [I 2025-11-12 23:02:21,030] Trial 6 finished with value: 0.12476122628510242 and parameters: {'learning_rate': 0.15910236549185625, 'num_leaves': 60, 'max_depth': 4, 'min_child_samples': 5, 'subsample': 0.8779030589088195, 'colsample_bytree': 0.8520079067034753, 'reg_alpha': 0.1840507310841318, 'reg_lambda': 0.001985275513509497}. Best is trial 3 with value: 0.11682934342392332.
# [I 2025-11-12 23:02:21,327] Trial 7 finished with value: 0.11903299350059361 and parameters: {'learning_rate': 0.04177307917875127, 'num_leaves': 73, 'max_depth': 3, 'min_child_samples': 97, 'subsample': 0.8606637955758143, 'colsample_bytree': 0.6690581045395616, 'reg_alpha': 0.7651879624256607, 'reg_lambda': 3.5010017654057637}. Best is trial 3 with value: 0.11682934342392332.
# [I 2025-11-12 23:02:22,396] Trial 8 finished with value: 0.11843489669510554 and parameters: {'learning_rate': 0.014365954891295973, 'num_leaves': 59, 'max_depth': 7, 'min_child_samples': 78, 'subsample': 0.9963198786447935, 'colsample_bytree': 0.878480726211051, 'reg_alpha': 0.004636849395233395, 'reg_lambda': 0.0014862893606252695}. Best is trial 3 with value: 0.11682934342392332.
# [I 2025-11-12 23:02:23,257] Trial 9 finished with value: 0.11827894723740133 and parameters: {'learning_rate': 0.03330860262319905, 'num_leaves': 182, 'max_depth': 4, 'min_child_samples': 7, 'subsample': 0.9096996037919104, 'colsample_bytree': 0.8610370173439603, 'reg_alpha': 2.6215934807534813, 'reg_lambda': 0.010021581947064238}. Best is trial 3 with value: 0.11682934342392332.
# [I 2025-11-12 23:02:26,201] Trial 10 finished with value: 0.1182818079906471 and parameters: {'learning_rate': 0.010043341529493972, 'num_leaves': 22, 'max_depth': 15, 'min_child_samples': 61, 'subsample': 0.5357426872775186, 'colsample_bytree': 0.5081904409248978, 'reg_alpha': 0.03481461670271357, 'reg_lambda': 0.027263801683570007}. Best is trial 3 with value: 0.11682934342392332.
# [I 2025-11-12 23:02:27,684] Trial 11 finished with value: 0.11792124521596573 and parameters: {'learning_rate': 0.01761474973333625, 'num_leaves': 117, 'max_depth': 11, 'min_child_samples': 51, 'subsample': 0.6235025753946803, 'colsample_bytree': 0.5955213656338695, 'reg_alpha': 0.0011472070319558385, 'reg_lambda': 3.238335665781051}. Best is trial 3 with value: 0.11682934342392332.
# [I 2025-11-12 23:02:28,871] Trial 12 finished with value: 0.1181881323083123 and parameters: {'learning_rate': 0.019189190805939955, 'num_leaves': 102, 'max_depth': 11, 'min_child_samples': 53, 'subsample': 0.7857800783058, 'colsample_bytree': 0.5100860188552858, 'reg_alpha': 0.07176668355161413, 'reg_lambda': 0.6266909582527637}. Best is trial 3 with value: 0.11682934342392332.
# [I 2025-11-12 23:02:29,770] Trial 13 finished with value: 0.11737790650089691 and parameters: {'learning_rate': 0.011980162133372427, 'num_leaves': 147, 'max_depth': 6, 'min_child_samples': 45, 'subsample': 0.6302880134437363, 'colsample_bytree': 0.7675716823667518, 'reg_alpha': 0.0025088715817622427, 'reg_lambda': 1.3140495132926089}. Best is trial 3 with value: 0.11682934342392332.
# [I 2025-11-12 23:02:30,425] Trial 14 finished with value: 0.11863456476192091 and parameters: {'learning_rate': 0.023609078421926683, 'num_leaves': 159, 'max_depth': 6, 'min_child_samples': 67, 'subsample': 0.6085089008026792, 'colsample_bytree': 0.7626577868068133, 'reg_alpha': 8.95328247154186, 'reg_lambda': 9.56200550451666}. Best is trial 3 with value: 0.11682934342392332.
# [I 2025-11-12 23:02:31,245] Trial 15 finished with value: 0.12300852866058029 and parameters: {'learning_rate': 0.09494873776239086, 'num_leaves': 150, 'max_depth': 6, 'min_child_samples': 19, 'subsample': 0.524308095106776, 'colsample_bytree': 0.7573907217146987, 'reg_alpha': 0.015344515218647272, 'reg_lambda': 0.11905702405990899}. Best is trial 3 with value: 0.11682934342392332.
# [I 2025-11-12 23:02:32,179] Trial 16 finished with value: 0.1166120573405916 and parameters: {'learning_rate': 0.010765690093010432, 'num_leaves': 102, 'max_depth': 6, 'min_child_samples': 32, 'subsample': 0.6043209086865857, 'colsample_bytree': 0.6525303379101673, 'reg_alpha': 0.1955016381418552, 'reg_lambda': 0.013145785328923142}. Best is trial 16 with value: 0.1166120573405916.
# [I 2025-11-12 23:02:32,497] Trial 17 finished with value: 0.12605041843289305 and parameters: {'learning_rate': 0.268035965812834, 'num_leaves': 100, 'max_depth': 3, 'min_child_samples': 30, 'subsample': 0.9318213587512639, 'colsample_bytree': 0.6657795533686942, 'reg_alpha': 0.2273640281301834, 'reg_lambda': 0.008491022165072911}. Best is trial 16 with value: 0.1166120573405916.
# [I 2025-11-12 23:02:33,134] Trial 18 finished with value: 0.11664751380243922 and parameters: {'learning_rate': 0.02126318124215678, 'num_leaves': 31, 'max_depth': 5, 'min_child_samples': 16, 'subsample': 0.8043029259490816, 'colsample_bytree': 0.6260612494294553, 'reg_alpha': 1.8723048941738407, 'reg_lambda': 0.006662808453474713}. Best is trial 16 with value: 0.1166120573405916.
# [I 2025-11-12 23:02:33,883] Trial 19 finished with value: 0.11717078117745502 and parameters: {'learning_rate': 0.023384081260739563, 'num_leaves': 21, 'max_depth': 8, 'min_child_samples': 13, 'subsample': 0.7916654638541845, 'colsample_bytree': 0.7169440110865314, 'reg_alpha': 0.7437796337072575, 'reg_lambda': 0.020041824455874754}. Best is trial 16 with value: 0.1166120573405916.
# [I 2025-11-12 23:02:34,546] Trial 20 finished with value: 0.11619785683855335 and parameters: {'learning_rate': 0.01622570905994197, 'num_leaves': 36, 'max_depth': 5, 'min_child_samples': 15, 'subsample': 0.6682455304893343, 'colsample_bytree': 0.6422175158816174, 'reg_alpha': 0.07769337737205838, 'reg_lambda': 0.005919281865998452}. Best is trial 20 with value: 0.11619785683855335.
# [I 2025-11-12 23:02:35,359] Trial 21 finished with value: 0.11617875903691462 and parameters: {'learning_rate': 0.017242385464699125, 'num_leaves': 43, 'max_depth': 5, 'min_child_samples': 13, 'subsample': 0.6725280321966531, 'colsample_bytree': 0.6368717248242541, 'reg_alpha': 0.09349896571422925, 'reg_lambda': 0.005820257777408474}. Best is trial 21 with value: 0.11617875903691462.
# [I 2025-11-12 23:02:36,358] Trial 22 finished with value: 0.11643055443216699 and parameters: {'learning_rate': 0.015689168245547502, 'num_leaves': 43, 'max_depth': 7, 'min_child_samples': 11, 'subsample': 0.6653214743630678, 'colsample_bytree': 0.551086991447026, 'reg_alpha': 0.0735978176477333, 'reg_lambda': 0.02297203906508314}. Best is trial 21 with value: 0.11617875903691462.
# [I 2025-11-12 23:02:39,939] Trial 23 finished with value: 0.1164353121775878 and parameters: {'learning_rate': 0.015901301973198737, 'num_leaves': 42, 'max_depth': 8, 'min_child_samples': 11, 'subsample': 0.6720027647671928, 'colsample_bytree': 0.5500887289852705, 'reg_alpha': 0.06712500078608728, 'reg_lambda': 0.04849582288202777}. Best is trial 21 with value: 0.11617875903691462.
# [I 2025-11-12 23:02:40,741] Trial 24 finished with value: 0.11770997446278074 and parameters: {'learning_rate': 0.03152501767327531, 'num_leaves': 41, 'max_depth': 5, 'min_child_samples': 20, 'subsample': 0.567994204713031, 'colsample_bytree': 0.5487218598003432, 'reg_alpha': 0.026118523876792178, 'reg_lambda': 0.004810712842651722}. Best is trial 21 with value: 0.11617875903691462.
# [I 2025-11-12 23:02:41,706] Trial 25 finished with value: 0.11919955669291009 and parameters: {'learning_rate': 0.04051458954445052, 'num_leaves': 41, 'max_depth': 9, 'min_child_samples': 7, 'subsample': 0.6661457314055439, 'colsample_bytree': 0.549085570823342, 'reg_alpha': 0.10276824199771895, 'reg_lambda': 0.003052593442004018}. Best is trial 21 with value: 0.11617875903691462.
# [I 2025-11-12 23:02:43,029] Trial 26 finished with value: 0.11751046666588692 and parameters: {'learning_rate': 0.016242704542814936, 'num_leaves': 46, 'max_depth': 7, 'min_child_samples': 25, 'subsample': 0.7460093226016469, 'colsample_bytree': 0.9994104029044079, 'reg_alpha': 0.03596088606489645, 'reg_lambda': 0.029487061649989238}. Best is trial 21 with value: 0.11617875903691462.
# [I 2025-11-12 23:02:43,731] Trial 27 finished with value: 0.12070065926176968 and parameters: {'learning_rate': 0.06634662558686533, 'num_leaves': 89, 'max_depth': 5, 'min_child_samples': 13, 'subsample': 0.6568074732196805, 'colsample_bytree': 0.7236230010971025, 'reg_alpha': 0.01186609506333256, 'reg_lambda': 0.1131846866748219}. Best is trial 21 with value: 0.11617875903691462.
# [I 2025-11-12 23:02:44,802] Trial 28 finished with value: 0.11866582170991093 and parameters: {'learning_rate': 0.02444781957406036, 'num_leaves': 198, 'max_depth': 7, 'min_child_samples': 38, 'subsample': 0.5761831372568553, 'colsample_bytree': 0.8073277037098299, 'reg_alpha': 0.11855970723322402, 'reg_lambda': 0.015637737777883867}. Best is trial 21 with value: 0.11617875903691462.
# [I 2025-11-12 23:02:45,863] Trial 29 finished with value: 0.1183645682883523 and parameters: {'learning_rate': 0.014032930405002158, 'num_leaves': 53, 'max_depth': 9, 'min_child_samples': 98, 'subsample': 0.703341502552186, 'colsample_bytree': 0.6235601721925554, 'reg_alpha': 0.4730754657451227, 'reg_lambda': 0.06886271828755727}. Best is trial 21 with value: 0.11617875903691462.
#
# Melhores hiperparâmetros encontrados:
#   learning_rate: 0.017242385464699125
#   num_leaves: 43
#   max_depth: 5
#   min_child_samples: 13
#   subsample: 0.6725280321966531
#   colsample_bytree: 0.6368717248242541
#   reg_alpha: 0.09349896571422925
#   reg_lambda: 0.005820257777408474
#
# MAPE (validação 80/20 temporal): 0.1162

# %%
import pandas as pd
import numpy as np
import holidays
import optuna
import time

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_percentage_error
from lightgbm import LGBMRegressor


def tunar_lightgbm_temporal_split(df, n_lags=4, test_size=0.2, n_trials=30, seed=42):
    """
    Faz tuning dos hiperparâmetros do LightGBM usando Optuna com split temporal fixo (80/20).
    Usa apenas as features temporais e os lags como preditoras.
    """

    df = df.copy()
    df.index = pd.to_datetime(df.index)

    # === Features temporais ===
    df['hora'] = df.index.hour
    df['dia_semana'] = df.index.dayofweek
    df['mes'] = df.index.month
    feriados_br = holidays.Brazil()
    df['feriado'] = df.index.map(lambda x: 1 if x in feriados_br else 0)

    # === Lags ===
    for i in range(1, n_lags + 1):
        df[f'lag_{i}'] = df['requisicoes'].shift(i)

    df = df.dropna()

    # === Selecionar apenas as colunas desejadas ===
    features = ['hora', 'dia_semana', 'mes', 'feriado'] + [f'lag_{i}' for i in range(1, n_lags + 1)]
    X = df[features]
    y = df['requisicoes']

    # === Split temporal 80/20 ===
    split_idx = int(len(df) * (1 - test_size))
    X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
    y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]

    # === Padronização ===
    scaler = StandardScaler()
    X_train_scaled = pd.DataFrame(
        scaler.fit_transform(X_train),
        index=X_train.index,
        columns=X_train.columns
    )
    X_test_scaled = pd.DataFrame(
        scaler.transform(X_test),
        index=X_test.index,
        columns=X_test.columns
    )

    # === Função objetivo para o Optuna ===
    def objective(trial):
        params = {
            "n_estimators": 500,
            "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
            "num_leaves": trial.suggest_int("num_leaves", 20, 200),
            "max_depth": trial.suggest_int("max_depth", 3, 15),
            "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
            "subsample": trial.suggest_float("subsample", 0.5, 1.0),
            "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
            "reg_alpha": trial.suggest_float("reg_alpha", 1e-3, 10.0, log=True),
            "reg_lambda": trial.suggest_float("reg_lambda", 1e-3, 10.0, log=True),
            "random_state": seed,
            "n_jobs": -1,
            "verbosity": -1
        }

        model = LGBMRegressor(**params)
        model.fit(X_train_scaled, y_train)

        y_pred = model.predict(X_test_scaled)
        mape = mean_absolute_percentage_error(y_test, y_pred)

        return mape

    # === Otimização com Optuna ===
    study = optuna.create_study(direction="minimize", study_name="LightGBM_TemporalSplit_Tuning")
    study.optimize(objective, n_trials=n_trials, show_progress_bar=True)

    print("\nMelhores hiperparâmetros encontrados:")
    for k, v in study.best_params.items():
        print(f"  {k}: {v}")
    print(f"\nMAPE (validação 80/20 temporal): {study.best_value:.4f}")

    return study

# %%
study = tunar_lightgbm_temporal_split(df)
# Out:
# [I 2025-11-12 23:22:22,281] A new study created in memory with name: LightGBM_TemporalSplit_Tuning
#   0%|          | 0/30 [00:00<?, ?it/s]
# [I 2025-11-12 23:22:23,147] Trial 0 finished with value: 0.15800273195702905 and parameters: {'learning_rate': 0.1548361200646292, 'num_leaves': 199, 'max_depth': 8, 'min_child_samples': 66, 'subsample': 0.9606277046339088, 'colsample_bytree': 0.6751335517464074, 'reg_alpha': 0.018235982530235888, 'reg_lambda': 4.837500373161069}. Best is trial 0 with value: 0.15800273195702905.
# [I 2025-11-12 23:22:24,283] Trial 1 finished with value: 0.16609846320101085 and parameters: {'learning_rate': 0.28065483956959175, 'num_leaves': 61, 'max_depth': 10, 'min_child_samples': 86, 'subsample': 0.8436552963378798, 'colsample_bytree': 0.6838230759225465, 'reg_alpha': 0.1355646072919714, 'reg_lambda': 9.268641849110812}. Best is trial 0 with value: 0.15800273195702905.
# [I 2025-11-12 23:22:29,176] Trial 2 finished with value: 0.15421099674344793 and parameters: {'learning_rate': 0.04014861906571153, 'num_leaves': 53, 'max_depth': 10, 'min_child_samples': 53, 'subsample': 0.7065941340244806, 'colsample_bytree': 0.8319788102386549, 'reg_alpha': 0.302260177911018, 'reg_lambda': 0.07911492113803117}. Best is trial 2 with value: 0.15421099674344793.
# [I 2025-11-12 23:22:30,406] Trial 3 finished with value: 0.15385924826579295 and parameters: {'learning_rate': 0.032781472880380816, 'num_leaves': 110, 'max_depth': 15, 'min_child_samples': 69, 'subsample': 0.6726057147007363, 'colsample_bytree': 0.9884225833482247, 'reg_alpha': 0.7746431076674338, 'reg_lambda': 0.5201537762361388}. Best is trial 3 with value: 0.15385924826579295.
# [I 2025-11-12 23:22:31,052] Trial 4 finished with value: 0.1581827437072703 and parameters: {'learning_rate': 0.07670073122626558, 'num_leaves': 91, 'max_depth': 12, 'min_child_samples': 60, 'subsample': 0.9702782669551082, 'colsample_bytree': 0.7108802067293503, 'reg_alpha': 0.22649978688745204, 'reg_lambda': 0.006855151339099794}. Best is trial 3 with value: 0.15385924826579295.
# [I 2025-11-12 23:22:31,551] Trial 5 finished with value: 0.1569165089878845 and parameters: {'learning_rate': 0.13630221111958882, 'num_leaves': 196, 'max_depth': 10, 'min_child_samples': 95, 'subsample': 0.9072823138825685, 'colsample_bytree': 0.5805138514776484, 'reg_alpha': 0.8608247805779875, 'reg_lambda': 1.692594509581113}. Best is trial 3 with value: 0.15385924826579295.
# [I 2025-11-12 23:22:31,815] Trial 6 finished with value: 0.15804299575652725 and parameters: {'learning_rate': 0.1784176300354546, 'num_leaves': 104, 'max_depth': 4, 'min_child_samples': 98, 'subsample': 0.9025430811486596, 'colsample_bytree': 0.9424835842052088, 'reg_alpha': 0.08941608640281641, 'reg_lambda': 0.03927422666786225}. Best is trial 3 with value: 0.15385924826579295.
# [I 2025-11-12 23:22:33,291] Trial 7 finished with value: 0.16077506895897922 and parameters: {'learning_rate': 0.10020008836246333, 'num_leaves': 192, 'max_depth': 15, 'min_child_samples': 12, 'subsample': 0.8491274928444452, 'colsample_bytree': 0.8453587555888422, 'reg_alpha': 4.382367249650166, 'reg_lambda': 0.009900490693240213}. Best is trial 3 with value: 0.15385924826579295.
# [I 2025-11-12 23:22:34,165] Trial 8 finished with value: 0.15272497884390485 and parameters: {'learning_rate': 0.016043109293091107, 'num_leaves': 182, 'max_depth': 11, 'min_child_samples': 63, 'subsample': 0.8625451283492731, 'colsample_bytree': 0.93449755734579, 'reg_alpha': 2.6338791277156717, 'reg_lambda': 0.287467407966696}. Best is trial 8 with value: 0.15272497884390485.
# [I 2025-11-12 23:22:34,845] Trial 9 finished with value: 0.1525546807494648 and parameters: {'learning_rate': 0.03088529549169966, 'num_leaves': 74, 'max_depth': 12, 'min_child_samples': 51, 'subsample': 0.8914025519033651, 'colsample_bytree': 0.6103352356938347, 'reg_alpha': 1.3729588327638451, 'reg_lambda': 8.21934810496807}. Best is trial 9 with value: 0.1525546807494648.
# [I 2025-11-12 23:22:35,176] Trial 10 finished with value: 0.1499999264011847 and parameters: {'learning_rate': 0.011394080678127232, 'num_leaves': 22, 'max_depth': 5, 'min_child_samples': 28, 'subsample': 0.5133796440130173, 'colsample_bytree': 0.5163017158406285, 'reg_alpha': 0.0015784287652275944, 'reg_lambda': 1.0960674336976626}. Best is trial 10 with value: 0.1499999264011847.
# [I 2025-11-12 23:22:35,431] Trial 11 finished with value: 0.15171524336734743 and parameters: {'learning_rate': 0.01080773265828476, 'num_leaves': 23, 'max_depth': 4, 'min_child_samples': 27, 'subsample': 0.5839386850184893, 'colsample_bytree': 0.5093016617478561, 'reg_alpha': 0.0016467195975231404, 'reg_lambda': 1.4072994119318376}. Best is trial 10 with value: 0.1499999264011847.
# [I 2025-11-12 23:22:35,732] Trial 12 finished with value: 0.1519609636386372 and parameters: {'learning_rate': 0.010156409318154428, 'num_leaves': 21, 'max_depth': 4, 'min_child_samples': 25, 'subsample': 0.51118152651121, 'colsample_bytree': 0.5166729342584351, 'reg_alpha': 0.0010503984550859747, 'reg_lambda': 0.7991958511212927}. Best is trial 10 with value: 0.1499999264011847.
# [I 2025-11-12 23:22:36,128] Trial 13 finished with value: 0.14930140773921416 and parameters: {'learning_rate': 0.01674910524102872, 'num_leaves': 27, 'max_depth': 6, 'min_child_samples': 31, 'subsample': 0.5146250540684632, 'colsample_bytree': 0.5097069916096506, 'reg_alpha': 0.001161272094569183, 'reg_lambda': 1.7912681999605808}. Best is trial 13 with value: 0.14930140773921416.
# [I 2025-11-12 23:22:36,681] Trial 14 finished with value: 0.15186648795872407 and parameters: {'learning_rate': 0.0186260321585806, 'num_leaves': 49, 'max_depth': 7, 'min_child_samples': 39, 'subsample': 0.5009193912361127, 'colsample_bytree': 0.5933843798609811, 'reg_alpha': 0.007282291913352232, 'reg_lambda': 0.0011110521907957678}. Best is trial 13 with value: 0.14930140773921416.
# [I 2025-11-12 23:22:37,224] Trial 15 finished with value: 0.14890427446024063 and parameters: {'learning_rate': 0.01970942173245813, 'num_leaves': 143, 'max_depth': 6, 'min_child_samples': 7, 'subsample': 0.60898427059843, 'colsample_bytree': 0.5576359299882294, 'reg_alpha': 0.006440024963745989, 'reg_lambda': 0.21670281165082605}. Best is trial 15 with value: 0.14890427446024063.
# [I 2025-11-12 23:22:37,847] Trial 16 finished with value: 0.14978585699670183 and parameters: {'learning_rate': 0.02143444077824054, 'num_leaves': 146, 'max_depth': 6, 'min_child_samples': 5, 'subsample': 0.6097690045622723, 'colsample_bytree': 0.6270677781199339, 'reg_alpha': 0.007849773499781323, 'reg_lambda': 0.14547228268513981}. Best is trial 15 with value: 0.14890427446024063.
# [I 2025-11-12 23:22:38,378] Trial 17 finished with value: 0.152585149844452 and parameters: {'learning_rate': 0.049097891846925236, 'num_leaves': 138, 'max_depth': 7, 'min_child_samples': 17, 'subsample': 0.5889689690606587, 'colsample_bytree': 0.7828138907149698, 'reg_alpha': 0.024993672494124854, 'reg_lambda': 0.030034968763936538}. Best is trial 15 with value: 0.14890427446024063.
# [I 2025-11-12 23:22:38,598] Trial 18 finished with value: 0.15462938602281615 and parameters: {'learning_rate': 0.027373454992333904, 'num_leaves': 141, 'max_depth': 3, 'min_child_samples': 38, 'subsample': 0.7617542693382177, 'colsample_bytree': 0.5613032809948003, 'reg_alpha': 0.00450539505229866, 'reg_lambda': 2.576496201785106}. Best is trial 15 with value: 0.14890427446024063.
# [I 2025-11-12 23:22:42,472] Trial 19 finished with value: 0.150853732062732 and parameters: {'learning_rate': 0.015633113770659256, 'num_leaves': 169, 'max_depth': 8, 'min_child_samples': 5, 'subsample': 0.6566949184050447, 'colsample_bytree': 0.6443199365980492, 'reg_alpha': 0.03710453733161484, 'reg_lambda': 0.3293077036813872}. Best is trial 15 with value: 0.14890427446024063.
# [I 2025-11-12 23:22:42,854] Trial 20 finished with value: 0.15302681752463954 and parameters: {'learning_rate': 0.061159763900935145, 'num_leaves': 158, 'max_depth': 6, 'min_child_samples': 37, 'subsample': 0.5579404125743785, 'colsample_bytree': 0.7473014152026104, 'reg_alpha': 0.0036671161355308554, 'reg_lambda': 0.20062210802734606}. Best is trial 15 with value: 0.14890427446024063.
# [I 2025-11-12 23:22:43,439] Trial 21 finished with value: 0.14867415049817195 and parameters: {'learning_rate': 0.021886317652738005, 'num_leaves': 132, 'max_depth': 6, 'min_child_samples': 5, 'subsample': 0.6411889891695189, 'colsample_bytree': 0.5529378120601733, 'reg_alpha': 0.009840710899482949, 'reg_lambda': 0.11145869713557816}. Best is trial 21 with value: 0.14867415049817195.
# [I 2025-11-12 23:22:43,900] Trial 22 finished with value: 0.1494097579126169 and parameters: {'learning_rate': 0.023203166290198585, 'num_leaves': 124, 'max_depth': 6, 'min_child_samples': 17, 'subsample': 0.6369449749693885, 'colsample_bytree': 0.55423439389292, 'reg_alpha': 0.012655840406359701, 'reg_lambda': 0.05519184151937214}. Best is trial 21 with value: 0.14867415049817195.
# [I 2025-11-12 23:22:44,741] Trial 23 finished with value: 0.1495146061239676 and parameters: {'learning_rate': 0.014393428540968593, 'num_leaves': 125, 'max_depth': 8, 'min_child_samples': 14, 'subsample': 0.7485875294935788, 'colsample_bytree': 0.5507526771681459, 'reg_alpha': 0.0031063652565567574, 'reg_lambda': 0.021829784407365365}. Best is trial 21 with value: 0.14867415049817195.
# [I 2025-11-12 23:22:45,053] Trial 24 finished with value: 0.14997352741972794 and parameters: {'learning_rate': 0.039252549112961624, 'num_leaves': 85, 'max_depth': 5, 'min_child_samples': 23, 'subsample': 0.7001509097445975, 'colsample_bytree': 0.5001557005748525, 'reg_alpha': 0.06112072809004013, 'reg_lambda': 0.11119950600130382}. Best is trial 21 with value: 0.14867415049817195.
# [I 2025-11-12 23:22:45,281] Trial 25 finished with value: 0.16066382888368 and parameters: {'learning_rate': 0.02353978731197077, 'num_leaves': 161, 'max_depth': 3, 'min_child_samples': 5, 'subsample': 0.5603395773847953, 'colsample_bytree': 0.644796561608351, 'reg_alpha': 0.001945621674380144, 'reg_lambda': 0.4674364521554391}. Best is trial 21 with value: 0.14867415049817195.
# [I 2025-11-12 23:22:45,795] Trial 26 finished with value: 0.15000310173984502 and parameters: {'learning_rate': 0.013888290090543275, 'num_leaves': 121, 'max_depth': 7, 'min_child_samples': 33, 'subsample': 0.5498612021755337, 'colsample_bytree': 0.5570026038027497, 'reg_alpha': 0.006495303359884384, 'reg_lambda': 3.1349343224030686}. Best is trial 21 with value: 0.14867415049817195.
# [I 2025-11-12 23:22:46,152] Trial 27 finished with value: 0.1518209955644479 and parameters: {'learning_rate': 0.019801456793003956, 'num_leaves': 102, 'max_depth': 5, 'min_child_samples': 44, 'subsample': 0.6202594338292305, 'colsample_bytree': 0.5974942918508978, 'reg_alpha': 9.906471214561181, 'reg_lambda': 0.01638595547954971}. Best is trial 21 with value: 0.14867415049817195.
# [I 2025-11-12 23:22:46,856] Trial 28 finished with value: 0.15142112251127207 and parameters: {'learning_rate': 0.027744037810671626, 'num_leaves': 150, 'max_depth': 9, 'min_child_samples': 20, 'subsample': 0.7742313866874442, 'colsample_bytree': 0.5341742153648206, 'reg_alpha': 0.012361181753474794, 'reg_lambda': 0.004151141983280539}. Best is trial 21 with value: 0.14867415049817195.
# [I 2025-11-12 23:22:47,427] Trial 29 finished with value: 0.15133358581659037 and parameters: {'learning_rate': 0.039835298353494246, 'num_leaves': 38, 'max_depth': 8, 'min_child_samples': 11, 'subsample': 0.6962897956316492, 'colsample_bytree': 0.6728797159568045, 'reg_alpha': 0.021805824174907593, 'reg_lambda': 4.356060039121152}. Best is trial 21 with value: 0.14867415049817195.
#
# Melhores hiperparâmetros encontrados:
#   learning_rate: 0.021886317652738005
#   num_leaves: 132
#   max_depth: 6
#   min_child_samples: 5
#   subsample: 0.6411889891695189
#   colsample_bytree: 0.5529378120601733
#   reg_alpha: 0.009840710899482949
#   reg_lambda: 0.11145869713557816
#
# MAPE (validação 80/20 temporal): 0.1487
